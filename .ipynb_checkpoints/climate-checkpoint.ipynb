# %%
#imports

import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import matplotlib.dates as mdates
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.seasonal import STL
from statsmodels.tsa.arima.model import ARIMA

dateparse = lambda x: datetime.strptime(x, "%Y-%m-%d")

# %%
def plot_time_series_data(df,col=value,date='date'):
    
    
        
    x = df.index.to_numpy()
    y = df[value].to_numpy()

    # Plot
    fig, ax = plt.subplots(figsize=(30,6))
    ax.plot(x, y, label=value)

    # Format the x-axis dates
    ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))  # Year-Month
    ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))  # tick every 3 months
    
    plt.xlabel("Date")
    plt.ylabel(value)
    plt.title(f"Time Series of {value}")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
def seasonality_decopositioin(df,period=12,plot=False):
    #the classical way, uses moving average

    result = seasonal_decompose(df, model='additive', period=period)
    
    if (plot is True):
        fig, axes = plt.subplots(4, 1, figsize=(12, 8), sharex=True)

        result.observed.plot(ax=axes[0], legend=False, title="Observed")
        result.trend.plot(ax=axes[1], legend=False, title="Trend")
        result.seasonal.plot(ax=axes[2], legend=False, title="Seasonal")
        result.resid.plot(ax=axes[3], legend=False, title="Residual")

        plt.tight_layout()
        plt.show()
    return result

# %%
def stl_decopose(df,period=12,plot=False):
    #uses LOESS decomosition, more robust
    
    stl = STL(df, period=period)
    result = stl.fit()
    
    if (plot is True):
        fig, axes = plt.subplots(4, 1, figsize=(12, 8), sharex=True)

        result.observed.plot(ax=axes[0], legend=False, title="Observed")
        result.trend.plot(ax=axes[1], legend=False, title="Trend")
        result.seasonal.plot(ax=axes[2], legend=False, title="Seasonal")
        result.resid.plot(ax=axes[3], legend=False, title="Residual")

        plt.tight_layout()
        plt.show()
    return result

# %%
def read_data(file_name, date="date"):
    
    data = pd.read_csv(file_name,parse_dates=[date], date_format= dateparse, index_col=date)
    return(data)

# %%
test
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2017-01-01  15.913043  85.869565    2.743478     59.000000
# 2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 2017-01-05  18.388889  74.944444    3.300000   1014.333333
# ...               ...        ...         ...           ...
# 2017-04-20  34.500000  27.500000    5.562500    998.625000
# 2017-04-21  34.250000  39.375000    6.962500    999.875000
# 2017-04-22  32.900000  40.900000    8.890000   1001.600000
# 2017-04-23  32.875000  27.500000    9.962500   1002.125000
# 2017-04-24  32.000000  27.142857   12.157143   1004.142857
#
# [114 rows x 4 columns]

# %%
train = read_data("DailyDelhiClimateTrain.csv")
test = read_data("DailyDelhiClimateTest.csv")

train
# Out:
#              meantemp    humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...               ...         ...         ...           ...
# 2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 4 columns]

# %%
plot_time_series_data(train,col="meantemp")

# %%
decomposed_signal = seasonality_decopositioin(train["meantemp"],period=365,plot=True)

# %%
stl_result = stl_decopose(train["meantemp"],period=365,plot=True)

# %%
period= 365
n_forecast = 114

data_deseasonal = stl_result.resid +stl_result.trend
model = ARIMA(data_deseasonal.dropna(), order=(1,0,1))
fit = model.fit()
forecast_data_deseasonal = fit.forecast(steps=n_forecast)



if(n_forecast< period):
    forecast_data_seasonal = stl_result.seasonal[-period-1:][0:n_forecast]
else:
    
    
final_forecast = forecast_data_deseasonal + forecast_data_seasonal
# Out:
# C:\Karim\AnacondaInstallation\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Karim\AnacondaInstallation\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Karim\AnacondaInstallation\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# date
# 2016-01-02   -14.213885
# 2016-01-03   -10.568705
# 2016-01-04    -9.996142
# 2016-01-05    -9.717213
# 2016-01-06    -9.267264
#                 ...
# 2016-04-20     7.673396
# 2016-04-21     7.249901
# 2016-04-22     6.554547
# 2016-04-23     5.477819
# 2016-04-24     4.660916
# Name: season, Length: 114, dtype: float64

# %%
# Plot
plt.figure(figsize=(12,6))
plt.plot(ts, label="Original")
plt.plot(pd.date_range(ts.index[-1]+pd.offsets.MonthEnd(), periods=n_forecast, freq='M'),
         final_forecast, label="Forecast", color='red')
plt.legend()
plt.show()
